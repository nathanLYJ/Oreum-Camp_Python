# %%
import random

def roll_2d6_plus_wisdom():
    dice1 = random.randint(1, 6)
    dice2 = random.randint(1, 6)
    wisdom_modifier = 0  # 아르골의 지혜 수정치. 필요하다면 이 값을 변경하세요.
    
    total = dice1 + dice2 + wisdom_modifier
    
    print(f"주사위1: {dice1}")
    print(f"주사위2: {dice2}")
    print(f"수정치: {wisdom_modifier}")
    print(f"총 합: {total}")
    
    return total

# 주사위 굴리기
result = roll_2d6_plus_wisdom()
# Out:
# 주사위1: 3
# 주사위2: 5
# 수정치: 0
# 총 합: 8

# %%
class Character:
    def __init__(self, name, profession, alignment):
        self.name = name
        self.profession = profession
        self.alignment = alignment
        self.abilities = {"STR": 0, "DEX": 0, "CON": 0, "INT": 0, "WIS": 0, "CHA": 0}
        self.hp = 0
        self.max_hp = 0
        self.skills = []
        self.special_abilities = []
        self.equipment = []
        self.background = ""
        self.relationships = {}
        self.notes = []

    def set_abilities(self, str, dex, con, int, wis, cha):
        self.abilities["STR"] = str
        self.abilities["DEX"] = dex
        self.abilities["CON"] = con
        self.abilities["INT"] = int
        self.abilities["WIS"] = wis
        self.abilities["CHA"] = cha

    def set_hp(self, hp):
        self.hp = hp
        self.max_hp = hp

    def add_skill(self, skill):
        self.skills.append(skill)

    def add_special_ability(self, ability):
        self.special_abilities.append(ability)

    def add_equipment(self, item):
        self.equipment.append(item)

    def set_background(self, background):
        self.background = background

    def add_relationship(self, name, description):
        self.relationships[name] = description

    def add_note(self, note):
        self.notes.append(note)

    def display_character_sheet(self):
        print(f"Name: {self.name}")
        print(f"Profession: {self.profession}")
        print(f"Alignment: {self.alignment}")
        print("\nAbilities:")
        for ability, value in self.abilities.items():
            print(f"  {ability}: {value:+d}")
        print(f"\nHP: {self.hp}/{self.max_hp}")
        print("\nSkills:")
        for skill in self.skills:
            print(f"  - {skill}")
        print("\nSpecial Abilities:")
        for ability in self.special_abilities:
            print(f"  - {ability}")
        print("\nEquipment:")
        for item in self.equipment:
            print(f"  - {item}")
        print(f"\nBackground: {self.background}")
        print("\nRelationships:")
        for name, description in self.relationships.items():
            print(f"  - {name}: {description}")
        print("\nNotes:")
        for note in self.notes:
            print(f"  - {note}")

# 아르골 캐릭터 생성
argol = Character("Argol (Orgol)", "Thief (Bard cover)", "Neutral")

# 능력치 설정
argol.set_abilities(0, 1, -1, 1, 0, 1)

# HP 설정 (예시 값, 실제 게임 규칙에 따라 조정 필요)
argol.set_hp(20)

# 스킬 추가
argol.add_skill("Infiltration")
argol.add_skill("Lock picking")
argol.add_skill("Pickpocketing")
argol.add_skill("Escape")
argol.add_skill("Singing")
argol.add_skill("Musical instrument")
argol.add_skill("Acting")
argol.add_skill("Persuasive speech")

# 특수 능력 추가
argol.add_special_ability("Dual Identity: Can use both Thief and Bard skills")
argol.add_special_ability("Charming Appearance: Advantage in social interactions")
argol.add_special_ability("Survival Instinct: Intuitive grasp of dangerous situations")

# 장비 추가
argol.add_equipment("Dagger")
argol.add_equipment("Leather armor")
argol.add_equipment("Adventure gear")
argol.add_equipment("Lyre")
argol.add_equipment("Thief's tools")

# 배경 설정
argol.set_background("Orphaned at a young age, learned thievery to support his sister. Uses bard persona as a cover.")

# 관계 추가
argol.add_relationship("Sister", "Only family, reason for his thieving life")

# 노트 추가
argol.add_note("Currently performing at the 'Dancing Mermaid' tavern in Silverhaven")

# 캐릭터 시트 표시
argol.display_character_sheet()
argol.add_note("은빛 장미단 정보: 항구 근처 창고 지역, 특히 오래된 어시장 뒤편 창고들을 자주 드나듦")
argol.add_note("은빛 장미단 정보: '붉은 등불' 선술집에서 목격됨")
argol.add_note("은빛 장미단 특징: 무장하고 다니며, 폭력적인 성향")
argol.add_note("항구 창고 지역 정찰: 희미한 불빛이 보이는 창고 발견")
argol.add_note("항구 창고 지역 정찰: 낮은 대화 소리와 새로운 발자국 자국 발견")
argol.add_note("은빛 장미단 조우: 두 명의 단원에게 붙잡힘")
argol.add_note("은빛 장미단 조우: 바드 신분을 주장했으나 의심받음")
argol.add_note("은빛 장미단을 칭송하는 즉흥 노래로 단원들의 신뢰 얻음")
argol.add_note("은빛 장미단 Boss와의 만남 제안 받음")
argol.add_note("은빛 장미단 멤버: 브록과 던컨")
argol.add_note("은빛 장미단의 자체 인식: 도시의 수호자, 로빈 후드와 같은 존재")
argol.add_note("은빛 장미단의 다음 목표: 다음 주 대형 보석상 강도 계획")
argol.add_note("은빛 장미단 보스: '실버 팽'이라 불림")
argol.add_note("실버 팽 특징: 뛰어난 검술 실력, 은빛 가면 착용, 강한 카리스마")
argol.add_note("은빛 장미단 역사: 약 10년 전 형성")
argol.add_note("은빛 장미단: 보스 '실버 팽'과의 만남 요청 거절됨")
argol.add_note("은빛 장미단 멤버들의 경계심 증가")
argol.add_note("은빛 장미단 멤버들과의 관계: 긴장 완화, 하지만 여전히 조심스러운 상태")
argol.add_note("요청받음: 은빛 장미단에 대한 노래 완성 시 들려주기 (정체를 직접적으로 드러내지 않는 선에서)")
argol.add_note("다음 만남 약속: 매주 금요일 밤, '붉은 등불' 선술집 근처")
argol.add_note("주의사항: 은빛 장미단과의 만남을 비밀로 유지할 것")
argol.add_note("의심: 은빛 장미단과 '춤추는 인어' 술집 주인 사이에 어떤 연관이 있을 가능성")
argol.add_note("'춤추는 인어' 주인: 상당한 영향력과 정보력을 가진 인물로 추정")
argol.add_note("은빛 장미단: '춤추는 인어' 주인을 경계하는 것으로 보임")
argol.add_note("은빛 장미단과의 대화 종료: 비밀 유지 약속, 노래 완성 시 '붉은 등불' 선술집 근처에서 만나기로 함")
argol.add_note("은빛 장미단을 위한 즉흥 노래 공연: 긍정적 반응 얻음")
argol.add_note("은빛 장미단과의 관계: 약간 개선됨, 하지만 여전히 완전한 신뢰는 얻지 못함")
argol.add_note("'실버 팽'에 대한 소문 수집: 대부분 신뢰성 낮은 정보. 성별, 외모, 과거 경력에 대한 모순된 소문들 존재.")
argol.add_note("충분한 휴식 취함: 부분적으로 회복됨")
argol.add_note("상류층에서의 '실버 팽' 정보: 고위 귀족들 사이에서 언급됨, 상인들에게 위협적 존재, 부패 관리 제압 소문 있음, 사교계의 흥미로운 소재")
argol.add_note("실버 팽 외모: 키가 크고 날렵한 체격, 날카로운 눈빛, 뛰어난 검술 실력")
argol.add_note("은빛 장미단 활동: 상인들로부터 '보호비' 수취, 부패 관리 타격")
argol.add_note("중요 증언자: 제화점 주인 (실버 팽을 직접 목격)")
argol.add_note("최근 사건: 세금 징수관 재산 강탈, 은빛 장미 흔적 남김")
argol.add_note("술집 주인의 은빛 장미단 견해: 필요악으로 인식, 양날의 검으로 비유")
argol.add_note("주의사항: 주인이 은빛 장미단에 대해 상당한 지식 보유, 하지만 주제의 위험성 인지")
argol.add_note("술집 주인의 정체: 은빛 장미단과 연락을 주고받는 핵심 정보원")
argol.add_note("주인의 계획: 은빛 장미단을 이용해 부패 관리 제거, 동시에 그들의 세력 견제")
argol.add_note("중요 사건: 세금 징수관 건은 계획보다 빨리 진행됨")
argol.add_note("제안 받음: 주인의 계획에 참여 요청")
argol.add_note("주인과의 계약: 동생의 안전과 생계 보장, 법적 구속력 있는 문서")
argol.add_note("주인의 본명 확보: 추후 협상이나 보호 수단으로 활용 가능")
argol.add_note("주요 타겟: 마커스 헤인즈 의원 (도시 개발 프로젝트 비리 연루)")
argol.add_note("아르골의 역할: 헤인즈 의원의 비서로 위장, 증거 수집")
argol.add_note("은빛 장미단 협조: 위장 신분 제공")
argol.add_note("주의: 주인의 의심 살짝 받음")
argol.add_note("계획 수정: 은빛 장미단을 위한 노래로 신뢰 구축")
argol.add_note("접선 장소: 붉은 등불 선술집, 주인이 몰래 감시 예정")
argol.add_note("실버 팽 정보: 왕실 근위대 출신 추정, 뛰어난 검술 실력, '은빛 섬광' 기술 보유")
argol.add_note("실버 팽 외모: 은빛 가면, 키가 크고 날렵한 체격, 낮고 침착한 목소리")
argol.add_note("실버 팽 철학: 부자에게서 빼앗아 가난한 자에게 줌, 극단적 정의감")
argol.add_note("실버 팽 특징: 오른팔에 큰 상처, 항상 검은 장갑으로 가림")
argol.add_note("노래 구상: '은빛 섬광, 정의의 칼날'을 주제로 한 구조 계획")
argol.add_note("작곡 과제: 실버 팽의 특징 은유적 표현, 노래의 전체적 분위기 결정")
argol.add_note("노래 구상 발전: 실버 팽의 상처를 투쟁과 희생의 상징으로 은유")
argol.add_note("주의점: 은빛 장미단을 능동적이고 적극적인 존재로 표현할 것")
argol.add_note("노래 구조 완성: 도입부, 1절, 후렴구, 2절, 브릿지, 마지막 후렴구로 구성")
argol.add_note("노래 주제: 실버 팽의 영웅성, 은빛 장미단의 단결력과 행동력, 정의와 희망")
argol.add_note("걸작 노래 완성: '은빛 섬광의 장미' - 실버 팽과 은빛 장미단을 주제로 한 영웅적 발라드")
argol.add_note("주인의 극찬: 노래의 잠재적 영향력 인정받음")
argol.add_note("노래 공개 계획: 1) '붉은 등불'에서 일부 공개 2) 은밀한 전체 공연 제안 3) 비밀 장소에서 전체 공연")
argol.add_note("주의사항: 초기에 최소한의 정보만 공개, 개인 안전 고려, 비밀 유지 확실히 할 것")
argol.add_note("수정된 계획 승인: 주의깊은 접근, 점진적 신뢰 구축, 안전 최우선")
argol.add_note("주의사항: 예상치 못한 상황에 대비한 철수 계획 필요")
argol.add_note("은빛 장미단 식별 방법: 왼쪽 손목의 은색 실팔찌, 특정 제스처(술잔 들 때 새끼손가락 구부림), '은빛 달빛' 암호문 사용, 특정 자리 선호")
argol.add_note("주의사항: 직접적인 식별 시도 금지, 그들이 먼저 접근하도록 유도")
argol.add_note("구체화된 공연 계획: 전략적 위치 선정, 은유적 의상 및 노래 구성, 특정 제스처 사용, 관객 상호작용 전략, 비상 계획 수립")
argol.add_note("주의사항: 모든 행동은 자연스럽게, 직접적인 접근 피하기")
argol.add_note("주인의 마지막 조언: 예상치 못한 상황 대비, 은빛 장미단의 시험에 대한 준비, 진짜 정체 숨기기")
argol.add_note("불명확한 조언: '그림자' 주의, 겉보기에 실패하는 것의 중요성")

# %% [markdown]
# 1. 능력치:
#    힘(STR): 0
#    민첩(DEX): +1
#    체질(CON): -1
#    지능(INT): +1
#    지혜(WIS): 0
#    매력(CHA): +1
#
# 2. 체력(HP):
#    (정확한 수치는 룰북 참조 필요)
#
# 3. 주요 능력:
#    - 도둑 스킬: 잠입, 잠금 해제, 소매치기, 도주
#    - 바드 스킬: 노래, 악기 연주, 연기, 설득력 있는 화술
#
# 4. 특수 능력:
#    - 이중 정체성: 바드와 도둑 스킬 모두 사용 가능
#    - 매력적인 외모: 사회적 상호작용에서 유리
#    - 생존 본능: 위험 상황 직감적 파악
#
# 5. 장비:
#    - 단검, 가죽 갑옷, 모험 장비, 리라, 도둑 도구 세트
#
# 6. 정렬: 중립
