# %% [markdown]
# ### Javascript 함수
# * 단위
# 	1. 절대 길이 단위: px (cm, mm, in, px, pt ....)
# 		- 고정된 크기를 나타냅니다
# 	2. 상대 길이 단위: %, vw, vh, em, rem (vmin, vmax)
# * 함수 선언
# 	1. 선언문:
# 	```js
# 	// 선언문
# 	function sum(x,y){
# 		return x+y;
# 	}
# 	//표현식
# 	let sumXY = function(x,y){
# 		return x+y
# 	};
# 	console.log(sum(10, 20));
# 	console.log(sumXY(10, 20));
# 	```
# 	2. 화살표 함수
# 	```js
# 	// 읽어볼만한 문헌 : https://ko.javascript.info/arrow-functions-basics
# 	function 함수1(x, y) {
#     return x + y
# 	}
# 	// 위 함수를 화살표 함수로 작성하면 아래와 같습니다.
# 	let 함수1 = (x, y) => x + y
#
# 	// 만악 함수 실행시 전달하는 인자가 한 개라면 소괄호를 생략할 수 있습니다.
# 	let 함수2 = x => x + 10
#
# 	// 화살표 함수 내부에서 한 줄 표현식만 반환한다면 return 키워드를 생략해도 됩니다.
# 	let 함수3 = x => x + 10
#
# 	let 결과 = 함수3(2);
#
# 	console.log(결과);
# 	```
# 	3. 즉시실행함수
# 	```js
# 	(function() {
#   	console.log('이 함수는 만들어지자마자 바로 실행됩니다!');
# 	})();
#
#
# 	(function() {
# 	document.querySelector(".btn").addEventListener("click", function(){
# 	console.log('click!')
# 	});
# 	})();
# 	```
# * 주석
# 	1. // 한줄 주석
# 	2. /* 여러줄 주석 */
# 	3. /**(여기서 Enter)*/ 주석 자동 셋팅
# * 사용자 입력 받을때
# 	window.prompt('값을 입력하세요')
# * 출력 console.log()은 개발자 도구화면에서만 출력 표시됩니다.
# * html 화면 출력 	document.getElementById('result').textContent = resultText;
# * [참고 자료](./javascript.html)
# * switch 문 여러 조건에 실행 코드를 작성
# 	```js
# 	switch (표현식) {
#   		case 값1:
#     // 값1에 대한 실행 코드
#     		break;
#   		case 값2:
#     // 값2에 대한 실행 코드
#     		break;
#   		...
#   		default:
#     // 모든 case에 해당하지 않을 때 실행될 코드
#     		break;
# 	}
# 	```
# * for 문
# 	```js
# 	const cars2 = ["BMW", "Volvo", "Saab", "Ford", "Flat", "Audi"];
# 	let text2 = ''
# 	for (let i = 0; i < cars2.length; i++) {
#     text2 += '<section><h2>' + cars2[i] + '</h2></section>'
# 	}
# 	text2
# 	```
# * do{}while{} 최소 1회 실행해야하는 코드에 사용
# * type
# 	1. 크게 두가지 타입으로 구분한다
# 		- 원시타입 - string, number, bigint, boolean, undefined, symbol, null
# 		- 객체타입 -

# %% [markdown]
# ### html 정의형 목록 추가
#
# ```html
# <p>Cryptids of Cornwall:</p>
#
# <dl>
#   <dt>Beast of Bodmin</dt> <!--제목-->
#   <dd>A large feline inhabiting Bodmin Moor.</dd><!--설명-->
#
#   <dt>Morgawr</dt>
#   <dd>A sea serpent.</dd>
#
#   <dt>Owlman</dt>
#   <dd>A giant owl-like creature.</dd>
# </dl>
# ```
